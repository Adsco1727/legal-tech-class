# %% [markdown]
# # Docassemble Governance Console
#
# Orchestration-only notebook for docassemble boundary checks and status review.

# %% [markdown]
# This notebook is for governance review only and does not perform deployments or ingestion.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
if not (repo_root / 'dpo_system').exists() and (repo_root.parent / 'dpo_system').exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

import dpo_system.src.kpi_summary as kpi_summary
import dpo_system.src.state_loader as state_loader
import dpo_system.src.sync_status as sync_status

print('Docassemble Governance Console ready')
print('Loaded:', kpi_summary.__name__, state_loader.__name__, sync_status.__name__)

# %%
from pathlib import Path
import sys

repo = Path.cwd().resolve()
if not (repo / "dpo_system").exists() and (repo.parent / "dpo_system").exists():
    repo = repo.parent
if str(repo) not in sys.path:
    sys.path.insert(0, str(repo))

from dpo_system.src import operator_actions as ops
from dpo_system.src import ledger_io as ledger

governance_id = ops.queue_governance_task(
    interview_name="wave4_governance_smoke",
    action_type="validate",
    priority=3,
    notes="notebook smoke: queue-only",
)

rows = ledger.read_sheet("GOVERNANCE_QUEUE")
print("queued governance_id:", governance_id)
print("GOVERNANCE_QUEUE rows:", len(rows))
print("last row:", rows[-1] if rows else None)
