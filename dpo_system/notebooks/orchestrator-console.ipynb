# %% [markdown]
# # Orchestrator Console
#
# Top-level notebook for control-plane review across the operator workflow.

# %% [markdown]
# This notebook is intentionally thin and only imports shared helpers. No live actions run here.

# %%
import sys
from pathlib import Path
import csv

repo = Path.cwd().resolve()
if not (repo / "dpo_system").exists() and (repo.parent / "dpo_system").exists():
    repo = repo.parent
if str(repo) not in sys.path:
    sys.path.insert(0, str(repo))

# Shared control-plane modules
import dpo_system.src.sync_status as sync_status
import dpo_system.src.operator_actions as operator_actions
import dpo_system.src.kpi_summary as kpi_summary

manifest_path = repo / "REPO_WAVE_MANIFEST.csv"
print("Manifest path:", manifest_path)

with open(manifest_path, newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

print("Orchestrator Console ready (imports + manifest inspection only).")

# %%
from pathlib import Path
import sys

repo = Path.cwd().resolve()
if not (repo / "dpo_system").exists() and (repo.parent / "dpo_system").exists():
    repo = repo.parent
if str(repo) not in sys.path:
    sys.path.insert(0, str(repo))

from dpo_system.src import operator_actions as ops
from dpo_system.src import ledger_io as ledger

crm_task_id = ops.queue_crm_task(
    lead_id="lead-wave4-smoke",
    action_type="update",
    priority=3,
    notes="notebook smoke: queue-only",
)

rows = ledger.read_sheet("CRM_QUEUE")
print("queued crm_task_id:", crm_task_id)
print("CRM_QUEUE rows:", len(rows))
print("last row:", rows[-1] if rows else None)
