# %% [markdown]
# # Clause Intelligence Console (Wave 4)
#
# Orchestration-only surface for operator review and controls.

# %% [markdown]
# Orchestration-only surface - no ingestion, no clause execution.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
if not (repo_root / 'dpo_system').exists() and (repo_root.parent / 'dpo_system').exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

import dpo_system.src.exception_report as exception_report
import dpo_system.src.queue_view as queue_view
import dpo_system.src.state_loader as state_loader

print('Clause Intelligence Console ready')
print('Loaded:', exception_report.__name__, queue_view.__name__, state_loader.__name__)

# %%
from pathlib import Path
import sys

repo = Path.cwd().resolve()
if not (repo / "dpo_system").exists() and (repo.parent / "dpo_system").exists():
    repo = repo.parent
if str(repo) not in sys.path:
    sys.path.insert(0, str(repo))

from dpo_system.src import operator_actions as ops
from dpo_system.src import ledger_io as ledger

clause_task_id = ops.queue_clause_task(
    contract_id="contract-wave4-smoke",
    clause_engine="ClauseX",
    analysis_type="classification",
    priority=3,
    notes="notebook smoke: queue-only",
)

rows = ledger.read_sheet("CLAUSE_QUEUE")
print("queued clause_task_id:", clause_task_id)
print("CLAUSE_QUEUE rows:", len(rows))
print("last row:", rows[-1] if rows else None)
